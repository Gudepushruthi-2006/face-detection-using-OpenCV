# %% [markdown]
# <a href="https://colab.research.google.com/github/Gudepushruthi-2006/face-detection-using-OpenCV/blob/main/Face_Detection_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f2abd629-8620-4dcb-ae26-bc42aad2bad6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2abd629-8620-4dcb-ae26-bc42aad2bad6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread("image(1).jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(611.5), np.float64(537.5), np.float64(-0.5))

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=5
)

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255,0,0), 2)

# %%
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=8)

if len(faces) == 0:
    print("No face detected")
else:
    print("Face detected:", len(faces))

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

plt.imshow(img)
plt.axis("off")
# Out:
# Face detected: 1
# (np.float64(-0.5), np.float64(611.5), np.float64(537.5), np.float64(-0.5))

# %%
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5bbe09fc-cb71-41d6-935c-c72d495e0e6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bbe09fc-cb71-41d6-935c-c72d495e0e6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread("image(4).webp")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(456.5), np.float64(639.5), np.float64(-0.5))

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=5
)

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255,0,0), 2)

# %%
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=8)

if len(faces) == 0:
    print("No face detected")
else:
    print("Face detected:", len(faces))

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

plt.imshow(img)
plt.axis("off")
# Out:
# Face detected: 2
# (np.float64(-0.5), np.float64(456.5), np.float64(639.5), np.float64(-0.5))
